# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score, matthews_corrcoef
from sklearn.model_selection import train_test_split

# %%
files_dict = {"Resilience":"percent_vsKR_scibert_Resilience.csv", 
                 "Biomarkers & Disease":"percent_vsKR_scibert_Biomarkers.csv", 
                 "Conditions":"percent_vsKR_scibert_Conditions.csv", 
                 "Stressors":"percent_vsKR_scibert_Stressors.csv"}

def plot(df, title):
    sns.set(color_codes=True)
    conf_values = df[["Negative Class Confidence Scores", "Postive Class Confidence Scores"]]
    sns.distplot(df["Negative Class Confidence Scores"].values, label="Negative Class")
    sns.distplot(df["Postive Class Confidence Scores"].values,  label="Positive Class")
    plt.legend()
    plt.title(title)
    sns.jointplot(x="Negative Class Confidence Scores", y="Postive Class Confidence Scores", data=conf_values);
    plt.show()

# %%
for i in files_dict.keys():
    print(i)
    df = pd.read_csv(filestwo_dict[i])
    plot(df, i +" Distrabution of Scores")
# Out:
# Resilience
# Biomarkers & Disease
# Conditions
# Stressors
